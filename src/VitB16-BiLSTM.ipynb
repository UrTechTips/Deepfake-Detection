# %%
import os
import sys
import pandas as pd
from pathlib import Path

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchvision.models import vit_b_16, ViT_B_16_Weights
import torchvision.transforms as transforms
from sklearn.model_selection import GroupShuffleSplit
from torch.optim.lr_scheduler import CosineAnnealingLR

from PIL import Image
from torch.utils.data import Dataset, DataLoader

from tqdm import tqdm
from sklearn.metrics import accuracy_score, roc_auc_score
import numpy as np

# %%
base_path = Path("/kaggle/input/faceswap-faces/")
batch_size = 4

# %%
df = pd.read_csv(base_path / "processed_metadata.csv")
df.head()
# Out:
#   video_id  frame_id label                                    filepath
# 0      437         0  REAL  processed_frames/original/437/437_0000.jpg
# 1      437         1  REAL  processed_frames/original/437/437_0001.jpg
# 2      437         2  REAL  processed_frames/original/437/437_0002.jpg
# 3      437         3  REAL  processed_frames/original/437/437_0003.jpg
# 4      437         4  REAL  processed_frames/original/437/437_0004.jpg

# %%
video_labels = df.groupby('video_id')['label'].first().reset_index()
video_labels
# Out:
#      video_id label
# 0         000  REAL
# 1     000_003  FAKE
# 2         001  REAL
# 3     001_870  FAKE
# 4         002  REAL
# ...       ...   ...
# 1995  997_040  FAKE
# 1996      998  REAL
# 1997  998_561  FAKE
# 1998      999  REAL
# 1999  999_960  FAKE
#
# [2000 rows x 2 columns]

# %%
video_labels.value_counts()
# Out:
# video_id  label
# 999_960   FAKE     1
# 000       REAL     1
# 000_003   FAKE     1
# 001       REAL     1
# 001_870   FAKE     1
#                   ..
# 009_027   FAKE     1
# 010       REAL     1
# 010_005   FAKE     1
# 011       REAL     1
# 011_805   FAKE     1
# Name: count, Length: 2000, dtype: int64

# %%
gss = GroupShuffleSplit(n_splits=1, test_size=0.3, random_state=69)
train_idx, temp_idx = next(gss.split(video_labels, video_labels['label'], groups=video_labels['video_id']))

train_videos = video_labels.iloc[train_idx]
temp_videos = video_labels.iloc[temp_idx]

gss2 = GroupShuffleSplit(n_splits=1, test_size=0.5, random_state=69)
val_idx, test_idx = next(gss2.split(temp_videos, temp_videos['label'], groups=temp_videos['video_id']))

val_videos = temp_videos.iloc[val_idx]
test_videos = temp_videos.iloc[test_idx]

train_df = df[df['video_id'].isin(train_videos['video_id'])]
val_df = df[df['video_id'].isin(val_videos['video_id'])]
test_df = df[df['video_id'].isin(test_videos['video_id'])]

train_df
# Out:
#       video_id  frame_id label  \
# 0          437         0  REAL
# 1          437         1  REAL
# 2          437         2  REAL
# 3          437         3  REAL
# 4          437         4  REAL
# ...        ...       ...   ...
# 99840  772_708        45  FAKE
# 99841  772_708        46  FAKE
# 99842  772_708        47  FAKE
# 99843  772_708        48  FAKE
# 99844  772_708        49  FAKE
#
#                                                 filepath
# 0             processed_frames/original/437/437_0000.jpg
# 1             processed_frames/original/437/437_0001.jpg
# 2             processed_frames/original/437/437_0002.jpg
# 3             processed_frames/original/437/437_0003.jpg
# 4             processed_frames/original/437/437_0004.jpg
# ...                                                  ...
# 99840  processed_frames/faceswap/772_708/772_708_0045...
# 99841  processed_frames/faceswap/772_708/772_708_0046...
# 99842  processed_frames/faceswap/772_708/772_708_0047...
# 99843  processed_frames/faceswap/772_708/772_708_0048...
# 99844  processed_frames/faceswap/772_708/772_708_0049...
#
# [69997 rows x 4 columns]

# %%
print("Train/Val/Test split summary:")
print(train_df['label'].value_counts())
print(val_df['label'].value_counts())
print(test_df['label'].value_counts())
# Out:
# Train/Val/Test split summary:
# label
# FAKE    35349
# REAL    34648
# Name: count, dtype: int64
# label
# REAL    7500
# FAKE    7500
# Name: count, dtype: int64
# label
# REAL    7849
# FAKE    7149
# Name: count, dtype: int64

# %%
train_vids = set(train_df['video_id'].unique())
val_vids = set(val_df['video_id'].unique())
test_vids = set(test_df['video_id'].unique())

print("Train∩Val:", len(train_vids & val_vids))
print("Train∩Test:", len(train_vids & test_vids))
print("Val∩Test:", len(val_vids & test_vids))

train_files = set(train_df['filepath'])
val_files   = set(val_df['filepath'])
print("Common files train/val:", len(train_files & val_files))
# Out:
# Train∩Val: 0
# Train∩Test: 0
# Val∩Test: 0
# Common files train/val: 0

# %%
class DeepfakeDataset(Dataset):
    def __init__(self, data, seq_length=50):
        self.df = data
        self.seq_length = seq_length
        self.videos = data['video_id'].unique()

    def __len__(self):
        return len(self.videos)

    def __getitem__(self, idx):
        vid = self.videos[idx]
        frames = self.df[self.df['video_id'] == vid]
        if len(frames) == 0:
            print(f"[WARN] Label {frames['label'][0]} Video {vid} has 0 frames in DataFrame")

        imgs = [Image.open(f"/kaggle/input/faceswap-faces/{fp}").convert('RGB') for fp in frames['filepath']]
        imgs = [self.transform(i) for i in imgs]
        imgs = torch.stack(imgs)
        imgs = self._add_padding(imgs)
        label = 1 if frames['label'].iloc[0] == 'FAKE' else 0
        return imgs, torch.tensor(label), vid

    def transform(self, img):
        if img.size != (224, 224):
            img = img.resize((224, 224))
        img_transform = transforms.Compose([
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomResizedCrop(224,scale=(0.8, 1.0)),
            transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1),
            transforms.ToTensor(),
            transforms.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225]),
        ])
        torch_tensor = img_transform(img)
        return torch_tensor

    def _add_padding(self, images):
        padding_needed = self.seq_length - images.size(0)
        if padding_needed > 0:
            pad_tensor = torch.zeros(padding_needed, 3, 224, 224)
            images_tensor = torch.cat((images, pad_tensor), dim=0)
            return images_tensor
        return images

# %%
train_dataset = DeepfakeDataset(train_df)
val_dataset = DeepfakeDataset(val_df)
test_dataset = DeepfakeDataset(test_df)

# %%
train_loader = DataLoader(train_dataset, batch_size = batch_size, shuffle=True, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size = batch_size, shuffle=True, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size = batch_size, shuffle=True, num_workers=4, pin_memory=True)

# %%
class TemporalStem(nn.Module):
    def __init__(self, in_channels=3, out_channels=64):
        super(TemporalStem, self).__init__()
        self.conv3d = nn.Conv3d(
            in_channels=in_channels,
            out_channels=out_channels,
            kernel_size=(3, 7, 7),  # temporal, height, width
            stride=(1, 2, 2),
            padding=(1, 3, 3)
        )
        self.bn = nn.BatchNorm3d(out_channels)
        self.relu = nn.ReLU(inplace=True)
        
    def forward(self, x):
        # Input: (B, C, T, H, W)
        x = self.conv3d(x)
        x = self.bn(x)
        x = self.relu(x)
        return x  # (B, 64, T, H/2, W/2)

# %%
VIT_FEATURE_DIM = 768     # ViT-B/32 feature dimension
LSTM_HIDDEN_SIZE = 512    # Hidden size for the LSTM layer
LSTM_NUM_LAYERS = 2       # Number of layers in the LSTM

class DetectionModel(nn.Module):
    def __init__(self, num_classes=2, hidden_size=LSTM_HIDDEN_SIZE, num_layers=LSTM_NUM_LAYERS):
        super(DetectionModel, self).__init__()
        self.vit = vit_b_16(weights=ViT_B_16_Weights.IMAGENET1K_V1)
        
        # Freeze ViT weights (optional but recommended for feature extraction)
        for param in self.vit.parameters():
            param.requires_grad = False
        for param in self.vit.encoder.layers[-1].parameters():
            param.requires_grad = True
            
        # Replace the final classification head with an identity layer 
        # to get the raw feature vector (768 dimensions) before the classifier.
        self.vit.heads.head = nn.Identity() 

        
        # 2. LSTM for Temporal Sequence Modeling
        # input_size is the feature dimension from the ViT (768)
        self.lstm = nn.LSTM(
            input_size=VIT_FEATURE_DIM,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,  # Tensors will be (batch_size, seq_len, features)
            bidirectional=True
        )

        num_heads = 4
        self.multihead_attn = nn.MultiheadAttention(
            embed_dim=hidden_size * 2,  # Total dimension from bidirectional LSTM
            num_heads=num_heads,        # Number of parallel heads
            batch_first=True            # IMPORTANT: Set this for LSTM output
        )

        
        # 3. Final Classifier Head
        # It takes the hidden state of the final layer of the LSTM.
        self.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(hidden_size * 2, 1)
        )

    def forward(self, x):
        # 1. Prepare for ViT (Per-Frame Processing)
        # x shape: (B, T, C, H, W)
        B, T, C, H, W = x.shape
        
        # Flatten (B, T) into a single pseudo-batch dimension: (B * T, C, H, W)
        x_flat = x.reshape(B * T, C, H, W)
        vit_features_flat = self.vit(x_flat)

        
        # 3. Prepare for LSTM (Sequence Re-formation)
        # Reshape features back into a sequence: (B, T, VIT_FEATURE_DIM)
        lstm_input = vit_features_flat.reshape(B, T, VIT_FEATURE_DIM)
        
        # 4. Sequence Modeling
        # h_n shape: (num_layers, B, hidden_size)
        lstm_out, _ = self.lstm(lstm_input)
        attn_output, _ = self.multihead_attn(lstm_out, lstm_out, lstm_out)
        context = torch.mean(attn_output, dim=1)
        # h_n_cat = torch.cat(h_n[-2], h_n[-1], dim=1)
        # 5. Classification
        # Get the hidden state of the *last* layer (h_n[-1]) for final prediction
        final_output = self.classifier(context)        # Output shape: (B, num_classes)
        
        return final_output

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device: ", device)

model = DetectionModel()
if device == "cuda":
    model = model.to(device)
# Out:
# Using device:  cuda
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100%|██████████| 330M/330M [00:01<00:00, 200MB/s]

# %%
num_epochs = 30
criterion = nn.BCEWithLogitsLoss(pos_weight=None, reduction='mean')  # More stable for binary tasks
optimizer = optim.AdamW([
    {"params": model.vit.encoder.layers[-1].parameters(), "lr": 1e-5},
    {"params": model.lstm.parameters()},
    {"params": model.classifier.parameters()}
], lr=1e-4, weight_decay=5e-5)
scheduler = optim.lr_scheduler.OneCycleLR(optimizer, max_lr = 1e-4, steps_per_epoch=len(train_loader), epochs=num_epochs)

# %%
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0, verbose=False):
        self.patience = patience
        self.min_delta = min_delta
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = float('inf')

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.min_delta:
            self.counter += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}). Saving model...')
        torch.save(model.state_dict(), 'checkpoint.pt')
        self.val_loss_min = val_loss

# %%
scaler = torch.amp.GradScaler('cuda')
early_stopping = EarlyStopping(patience=7, verbose=True)

train_losses = []
val_losses = []
val_accuracies = []


for epoch in range(num_epochs):
    print("\n" + "="*50)
    print(f"Running Epoch: {epoch+1}/{num_epochs}")
    print("="*50)
    
    # ------------------
    # 1. Training Phase (Sequence-level)
    # ------------------
    model.train()
    train_loss = 0
    
    # imgs shape: (B, T, C, H, W), labels shape: (B), _ (vids)
    for imgs, labels, _ in tqdm(train_loader, desc="Training", file=sys.stdout):
        
        # Move video sequence batch to device
        imgs = imgs.to(device)
        labels = labels * 0.9 + 0.05
        
        # Move and format labels: (B) -> (B, 1) float for BCEWithLogitsLoss
        labels = labels.float().unsqueeze(1).to(device)

        optimizer.zero_grad()
        
        # Autocast enables mixed precision for the forward pass
        with torch.amp.autocast(device):
            # Forward pass: model expects (B, T, C, H, W) and outputs (B, 1)
            outputs = model(imgs) 
            loss = criterion(outputs, labels)

        # Scale loss, backpropagate, and update
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        train_loss += loss.item()

    avg_train_loss = train_loss / len(train_loader)
    
    # Step the learning rate scheduler after the epoch
    scheduler.step()
    
    # ------------------
    # 2. Validation Phase (Sequence-level)
    # ------------------
    model.eval()
    per_video_rows = []
    val_loss = 0
    
    with torch.no_grad():
        for imgs, labels, vids in val_loader:
            B, _, _, _, _ = imgs.shape
            
            # Pass the entire sequence batch (B, T, C, H, W) to the model
            imgs = imgs.to(device)
            labels = labels.float().unsqueeze(1).to(device)
            
            # Forward pass, outputs are logits (B, 1)
            outputs = model(imgs) 
            loss = criterion(outputs, labels)

            val_loss += loss.item()
            
            # Apply sigmoid to get video prediction probabilities and flatten (B,)
            video_preds = torch.sigmoid(outputs).cpu().numpy().ravel()
            
            for i in range(B):
                per_video_rows.append({
                    'video_id': vids[i],
                    # Direct score from the model's output
                    'pred': float(video_preds[i]), 
                    'label': int(labels[i].item())
                })
    avg_val_loss = val_loss / len(val_loader)
    
    # --- Evaluation ---
    video_df_pred = pd.DataFrame(per_video_rows)
    # Only keep one prediction per video, although the current loader only provides one.
    video_df_pred = video_df_pred.drop_duplicates(subset='video_id') 
    
    # Ensure there are enough samples and both classes for meaningful metrics
    if len(video_df_pred) > 1 and len(video_df_pred['label'].unique()) > 1:
        auc = roc_auc_score(video_df_pred['label'], video_df_pred['pred'])
    else:
        auc = 0.0
        print("Warning: Insufficient data for AUC calculation.")

    acc = accuracy_score(video_df_pred['label'], (video_df_pred['pred'] > 0.5).astype(int))

    early_stopping(avg_val_loss, model)
    if early_stopping.early_stop:
        print("Early stopping triggered.")
        break

    train_losses.append(avg_train_loss) 
    val_losses.append(avg_val_loss)
    val_accuracies.append(acc)

    if (epoch + 1) == 3:
        for param in model.vit.encoder.layers[-1].parameters():
            param.requires_grad = True

        optimizer = optim.AdamW([
            {"params": model.vit.encoder.layers[-1].parameters(), "lr": 1e-5},
            {"params": model.lstm.parameters()},
            {"params": model.classifier.parameters()}
        ], lr=1e-4, weight_decay=5e-5)
        scheduler = optim.lr_scheduler.OneCycleLR(optimizer, max_lr = 1e-4, steps_per_epoch=len(train_loader), epochs=num_epochs)
                
    # ------------------
    # 3. Epoch Summary
    # ------------------
    print("\n" + "*"*60)
    print(f"Epoch {epoch+1} Summary:")
    print(f"| Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f} | Val AUC: {auc:.4f} | Val Acc: {acc:.4f} |")
    # print("\nPrediction Score Distribution:")
    # print(video_df_pred['pred'].describe().to_string())
    print("\n" + "*"*60)
# Out:
# ==================================================
# Running Epoch: 1/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:05<00:00,  1.39s/it]
# Validation loss decreased (inf --> 0.691108). Saving model...
#
# ************************************************************
# Epoch 1 Summary:
# | Train Loss: 0.6930 | Val Loss: 0.6911 | Val AUC: 0.6595 | Val Acc: 0.6233 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 2/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# Validation loss decreased (0.691108 --> 0.687619). Saving model...
#
# ************************************************************
# Epoch 2 Summary:
# | Train Loss: 0.6894 | Val Loss: 0.6876 | Val AUC: 0.6701 | Val Acc: 0.5533 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 3/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# Validation loss decreased (0.687619 --> 0.679250). Saving model...
#
# ************************************************************
# Epoch 3 Summary:
# | Train Loss: 0.6833 | Val Loss: 0.6793 | Val AUC: 0.7106 | Val Acc: 0.6400 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 4/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# Validation loss decreased (0.679250 --> 0.658335). Saving model...
#
# ************************************************************
# Epoch 4 Summary:
# | Train Loss: 0.6690 | Val Loss: 0.6583 | Val AUC: 0.7639 | Val Acc: 0.6733 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 5/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:03<00:00,  1.38s/it]
# Validation loss decreased (0.658335 --> 0.578164). Saving model...
#
# ************************************************************
# Epoch 5 Summary:
# | Train Loss: 0.6187 | Val Loss: 0.5782 | Val AUC: 0.8160 | Val Acc: 0.7233 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 6/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:03<00:00,  1.38s/it]
# Validation loss decreased (0.578164 --> 0.462182). Saving model...
#
# ************************************************************
# Epoch 6 Summary:
# | Train Loss: 0.5144 | Val Loss: 0.4622 | Val AUC: 0.8778 | Val Acc: 0.8033 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 7/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# Validation loss decreased (0.462182 --> 0.406253). Saving model...
#
# ************************************************************
# Epoch 7 Summary:
# | Train Loss: 0.4488 | Val Loss: 0.4063 | Val AUC: 0.9063 | Val Acc: 0.8267 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 8/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# Validation loss decreased (0.406253 --> 0.389395). Saving model...
#
# ************************************************************
# Epoch 8 Summary:
# | Train Loss: 0.4103 | Val Loss: 0.3894 | Val AUC: 0.9187 | Val Acc: 0.8467 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 9/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# Validation loss decreased (0.389395 --> 0.364372). Saving model...
#
# ************************************************************
# Epoch 9 Summary:
# | Train Loss: 0.3828 | Val Loss: 0.3644 | Val AUC: 0.9237 | Val Acc: 0.8367 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 10/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# EarlyStopping counter: 1 out of 7
#
# ************************************************************
# Epoch 10 Summary:
# | Train Loss: 0.3603 | Val Loss: 0.3689 | Val AUC: 0.9318 | Val Acc: 0.8367 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 11/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# Validation loss decreased (0.364372 --> 0.331356). Saving model...
#
# ************************************************************
# Epoch 11 Summary:
# | Train Loss: 0.3518 | Val Loss: 0.3314 | Val AUC: 0.9424 | Val Acc: 0.8600 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 12/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# EarlyStopping counter: 1 out of 7
#
# ************************************************************
# Epoch 12 Summary:
# | Train Loss: 0.3318 | Val Loss: 0.3755 | Val AUC: 0.9372 | Val Acc: 0.8567 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 13/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# EarlyStopping counter: 2 out of 7
#
# ************************************************************
# Epoch 13 Summary:
# | Train Loss: 0.3323 | Val Loss: 0.3406 | Val AUC: 0.9529 | Val Acc: 0.8667 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 14/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# Validation loss decreased (0.331356 --> 0.290467). Saving model...
#
# ************************************************************
# Epoch 14 Summary:
# | Train Loss: 0.3101 | Val Loss: 0.2905 | Val AUC: 0.9558 | Val Acc: 0.8867 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 15/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# EarlyStopping counter: 1 out of 7
#
# ************************************************************
# Epoch 15 Summary:
# | Train Loss: 0.3048 | Val Loss: 0.2907 | Val AUC: 0.9542 | Val Acc: 0.9000 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 16/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:03<00:00,  1.38s/it]
# EarlyStopping counter: 2 out of 7
#
# ************************************************************
# Epoch 16 Summary:
# | Train Loss: 0.2856 | Val Loss: 0.2979 | Val AUC: 0.9600 | Val Acc: 0.8800 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 17/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# Validation loss decreased (0.290467 --> 0.256679). Saving model...
#
# ************************************************************
# Epoch 17 Summary:
# | Train Loss: 0.2862 | Val Loss: 0.2567 | Val AUC: 0.9673 | Val Acc: 0.9067 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 18/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# EarlyStopping counter: 1 out of 7
#
# ************************************************************
# Epoch 18 Summary:
# | Train Loss: 0.2640 | Val Loss: 0.2704 | Val AUC: 0.9674 | Val Acc: 0.9000 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 19/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# EarlyStopping counter: 2 out of 7
#
# ************************************************************
# Epoch 19 Summary:
# | Train Loss: 0.2582 | Val Loss: 0.2682 | Val AUC: 0.9641 | Val Acc: 0.8933 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 20/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:03<00:00,  1.38s/it]
# Validation loss decreased (0.256679 --> 0.246801). Saving model...
#
# ************************************************************
# Epoch 20 Summary:
# | Train Loss: 0.2787 | Val Loss: 0.2468 | Val AUC: 0.9697 | Val Acc: 0.9100 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 21/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:03<00:00,  1.38s/it]
# EarlyStopping counter: 1 out of 7
#
# ************************************************************
# Epoch 21 Summary:
# | Train Loss: 0.2438 | Val Loss: 0.2709 | Val AUC: 0.9650 | Val Acc: 0.9033 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 22/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:03<00:00,  1.38s/it]
# EarlyStopping counter: 2 out of 7
#
# ************************************************************
# Epoch 22 Summary:
# | Train Loss: 0.2519 | Val Loss: 0.2736 | Val AUC: 0.9646 | Val Acc: 0.9067 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 23/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:03<00:00,  1.38s/it]
# EarlyStopping counter: 3 out of 7
#
# ************************************************************
# Epoch 23 Summary:
# | Train Loss: 0.2414 | Val Loss: 0.2689 | Val AUC: 0.9656 | Val Acc: 0.9133 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 24/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# EarlyStopping counter: 4 out of 7
#
# ************************************************************
# Epoch 24 Summary:
# | Train Loss: 0.2333 | Val Loss: 0.2662 | Val AUC: 0.9648 | Val Acc: 0.9033 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 25/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:03<00:00,  1.38s/it]
# EarlyStopping counter: 5 out of 7
#
# ************************************************************
# Epoch 25 Summary:
# | Train Loss: 0.2297 | Val Loss: 0.2559 | Val AUC: 0.9678 | Val Acc: 0.9133 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 26/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# Validation loss decreased (0.246801 --> 0.240109). Saving model...
#
# ************************************************************
# Epoch 26 Summary:
# | Train Loss: 0.2377 | Val Loss: 0.2401 | Val AUC: 0.9712 | Val Acc: 0.9267 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 27/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# EarlyStopping counter: 1 out of 7
#
# ************************************************************
# Epoch 27 Summary:
# | Train Loss: 0.2248 | Val Loss: 0.3013 | Val AUC: 0.9679 | Val Acc: 0.8767 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 28/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# EarlyStopping counter: 2 out of 7
#
# ************************************************************
# Epoch 28 Summary:
# | Train Loss: 0.2487 | Val Loss: 0.3062 | Val AUC: 0.9623 | Val Acc: 0.8767 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 29/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# EarlyStopping counter: 3 out of 7
#
# ************************************************************
# Epoch 29 Summary:
# | Train Loss: 0.2272 | Val Loss: 0.2994 | Val AUC: 0.9632 | Val Acc: 0.8933 |
#
# ************************************************************
#
# ==================================================
# Running Epoch: 30/30
# ==================================================
# Training: 100%|██████████| 350/350 [08:02<00:00,  1.38s/it]
# EarlyStopping counter: 4 out of 7
#
# ************************************************************
# Epoch 30 Summary:
# | Train Loss: 0.2228 | Val Loss: 0.2557 | Val AUC: 0.9666 | Val Acc: 0.9133 |
#
# ************************************************************

# %%
# Test Dataset stuff
def test_model(model):
    model.eval()
    per_video_rows = []
    test_loss = 0
    
    with torch.no_grad():
        for imgs, labels, vids in test_loader:
            B, _, _, _, _ = imgs.shape
            
            # Pass the entire sequence batch (B, T, C, H, W) to the model
            imgs = imgs.to(device)
            labels = labels.float().unsqueeze(1).to(device)
            
            # Forward pass, outputs are logits (B, 1)
            outputs = model(imgs) 
            loss = criterion(outputs, labels)
    
            test_loss += loss.item()
            
            # Apply sigmoid to get video prediction probabilities and flatten (B,)
            video_preds = torch.sigmoid(outputs).cpu().numpy().ravel()
            
            for i in range(B):
                per_video_rows.append({
                    'video_id': vids[i],
                    # Direct score from the model's output
                    'pred': float(video_preds[i]), 
                    'label': int(labels[i].item())
                })
    
    avg_test_loss = test_loss / len(test_loader)
    # --- Evaluation ---
    video_df_pred = pd.DataFrame(per_video_rows)
    # Only keep one prediction per video, although the current loader only provides one.
    video_df_pred = video_df_pred.drop_duplicates(subset='video_id') 
    
    # Ensure there are enough samples and both classes for meaningful metrics
    if len(video_df_pred) > 1 and len(video_df_pred['label'].unique()) > 1:
        auc = roc_auc_score(video_df_pred['label'], video_df_pred['pred'])
    else:
        auc = 0.0
        print("Warning: Insufficient data for AUC calculation.")
    
    acc = accuracy_score(video_df_pred['label'], (video_df_pred['pred'] > 0.5).astype(int))
        
    # ------------------
    # 3. Epoch Summary
    # ------------------
    print("\n" + "*"*60)
    print(f"Test Summary:")
    print(f"| Test Loss: {avg_test_loss:.4f} | Val AUC: {auc:.4f} | Val Acc: {acc:.4f} |")
    # print("\nPrediction Score Distribution:")
    # print(video_df_pred['pred'].describe().to_string())
    print("\n" + "*"*60)

test_model(model)
# Out:
# ************************************************************
# Test Summary:
# | Test Loss: 0.3206 | Val AUC: 0.9534 | Val Acc: 0.8767 |
#
# ************************************************************

# %%
torch.save(model.state_dict(), "model_state.pth")

# %%
# Create a new instance of the model
model2 = DetectionModel()

# Load the saved state dictionary
checkpoint_dict = torch.load("checkpoint.pt")

# Load the state dict into the model IN-PLACE
model2.load_state_dict(checkpoint_dict)

# Now, move the model to the correct device
if device == "cuda":
    model2 = model2.to(device)

# Test the model
test_model(model2)
# Out:
# ************************************************************
# Test Summary:
# | Test Loss: 0.3213 | Val AUC: 0.9514 | Val Acc: 0.8867 |
#
# ************************************************************

# %%
import matplotlib.pyplot as plt

num_epochs_run = len(train_losses) 
epochs = range(1, num_epochs_run + 1) # X-axis data

# Plot 1: Loss Curves
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_losses, label='Training Loss', marker='.')
plt.plot(epochs, val_losses, label='Validation Loss', marker='.')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot 2: Accuracy Curve
plt.figure(figsize=(10, 5))
plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='green', marker='.')
plt.title('Validation Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
